# %%
import serial
import serial.tools.list_ports
ports = serial.tools.list_ports.comports()
print(ports)
for index, value in enumerate(sorted(ports)):
    print(index, '\t', value.name, '\t', value.manufacturer)
# Out:
# ...
# 0 	 COM3 	 Intel

# %%
import pandas as pd
# first testing with increased counterweight. Inverted
data =pd.read_csv('logs/realtime_log_20260605_102102.csv')
data.plot(xlim=[1000, 2300])
# Out:
# <Axes: >

# %% [markdown]
# ## constant Gradient
# This implies constant torque = torque from gravity at theta err
#
# blue is the angular speed of the motor
#
#
# kp = -60
# v=24v
# A=1.3 peak
# float MAX_VOLTAGE = 15;

# %%
import pandas as pd
# first testing with increased counterweight. Inverted
data =pd.read_csv('data/video 2 stable 20.csv')
data.plot()
# Out:
# <Axes: >

# %%
import pandas as pd
# first testing with increased counterweight. Inverted
data =pd.read_csv('data/video3 stable 5.csv')
data.plot()
# Out:
# <Axes: >

# %%
import os
import pandas as pd

for i in os.listdir('data'):
    # first testing with increased counterweight. Inverted
    data =pd.read_csv('data/10v test 2053A.csv')
    data.plot()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[22], line 6
#       2 import pandas as pd
#       4 for i in os.listdir('data'):
#       5     # first testing with increased counterweight. Inverted
# ----> 6     data =pd.read_csv('data/10v test 2053A.csv')
#       7     data.plot()
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# first testing with increased counterweight. Inverted
data = pd.read_csv('data/stabilised.csv')
data.head()
# data.plot(xlim=[1000, 1050], y='theta', ylim=[200, 300])
# data.plot(xlim=[1000, 1050], y='motor_vel')

time = data['time']
theta = data['theta']
mv = data['motor_vel']
plt.plot(theta -281.5)
# plt.plot(mv)
plt.xlim(800, 1500)
plt.ylim(-50, 50)
print(float(time[1500][-6:]) - float(time[800][-6:]))

# Source - https://stackoverflow.com/a/19472896
# Posted by Martijn Pieters, modified by community. See post 'Timeline' for change history
# Retrieved 2026-06-10, License - CC BY-SA 3.0
# Out:
# 32.891000000000005

# %%
import matplotlib.pyplot as plt
import numpy as np





data = pd.read_csv('data/stabilised.csv')
data.head()
# data.plot(xlim=[1000, 1050], y='theta', ylim=[200, 300])
# data.plot(xlim=[1000, 1050], y='motor_vel')

t = data['time']
theta = data['theta']
mv = data['motor_vel']


fig, ax1 = plt.subplots()

color = 'tab:blue'
ax1.set_xlabel('time (s)')
ax1.set_ylabel('exp', color=color)
ax1.plot(mv, color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(-40, 40)

ax2 = ax1.twinx()  # instantiate a second Axes that shares the same x-axis

color = 'orange'
ax2.set_ylabel('sin', color=color)  # we already handled the x-label with ax1
ax2.plot(theta, color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(270, 300)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.xlim(700, 1060)
plt.show()
